# %%
from google.colab import drive
drive.mount('/content/drive')

import os
import pandas as pd

# Caminho do diretório
directory_path = '/content/drive/My Drive/Ciência da Computação/2024.1/Inteligência Artificial/Projeto Final'

# Listando os arquivos no diretório
files = os.listdir(directory_path)
print("Arquivos no diretório:", files)

# Caminho completo do arquivo Excel
file_path = os.path.join(directory_path, 'Frente02.xlsx')

# Verificando se o arquivo existe
if 'Frente02.xlsx' in files:
    # Carregando o DataFrame
    df = pd.read_excel(file_path)
    # Imprimindo as 5 primeiras linhas do DataFrame
    print(df.head())
else:
    print("Arquivo Frente02.xlsx não encontrado no diretório.")

# %%
#Montando o caminho para o Google Drive

from google.colab import drive
drive.mount('/content/drive')

# %%
import os

# Caminho do diretório
directory_path = '/content/drive/My Drive/Ciência da Computação/2024.1/Inteligência Artificial/Projeto Final'

# Listando os arquivos no diretório
files = os.listdir(directory_path)
print(files)

# %%
import pandas as pd

# Caminho completo do arquivo Excel
file_path = '/content/drive/My Drive/Ciência da Computação/2024.1/Inteligência Artificial/Projeto Final/Frente02.xlsx'

# Carregando o DataFrame
df = pd.read_excel(file_path)

# Imprimindo as 5 primeiras linhas do DataFrame
print(df.head())

# %%
# Importando a biblioteca pandas
import pandas as pd

# Lendo o arquivo Excel.
data_path = ('/Frente02')

# %%
# prompt: imprima na tela as 5 primeiras linhas do datapath

import pandas as pd

# Lendo o arquivo Excel.
data_path = ('/Frente02')

# Carregando o DataFrame
df = pd.read_excel(data_path)

# Imprimindo as 5 primeiras linhas do DataFrame
print(df.head())

# %%
import pandas as pd
from google.colab import drive

# Montando o Google Drive
drive.mount('/content/drive')

# Caminho do arquivo Excel no Google Drive
data_path = '/content/drive/My Drive/Ciência da Computação/2024.1/Inteligência Artificial/Projeto Final/Frente02.csv'

df_frente02 = pd.DataFrame(dados, columns = ['Livro Lido', 'Motivo do Gostar', 'Livros Recomendados'])

# %%
import pandas as pd
from google.colab import drive

# Montando o Google Drive
drive.mount('/content/drive')

# Caminho do arquivo Excel no Google Drive
data_path = '/content/drive/My Drive/Ciência da Computação/2024.1/Inteligência Artificial/Projeto Final/Frente02.csv'

# Lendo os dados do arquivo (substitua 'dados' pelos dados reais)
dados = pd.read_csv(data_path)  # Assuming your file is a CSV

df_frente02 = pd.DataFrame(dados, columns = ['Livro Lido', 'Motivo do Gostar', 'Livros Recomendados'])

# %%
import pandas as pd

dados = pd.read_csv('/content/drive/My Drive/Ciência da Computação/2024.1/Inteligência Artificial/Projeto Final/Frente02.csv')
